# %% [markdown]
# # Demos
#
# Let's run a few demos to test our installation.
#
# First, note that this cell is a "markdown" cell. Each cell can be specified as a type. The default is to assume it is a "code" cell. You can change this type setting by selecting the cell you want to change and going into the cell->Cell Type menu.
#
# Now, let's try a few demos....

# %%
from bokeh.plotting import figure
from bokeh.io import push_notebook, show, output_notebook
output_notebook()

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
t=show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="408f0142-f763-4bb2-8936-7a6e12aecc62">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="0842f3d0-f48c-40f9-b4ee-d2a7260a9816"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0842f3d0-f48c-40f9-b4ee-d2a7260a9816");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0842f3d0-f48c-40f9-b4ee-d2a7260a9816' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a45e2878-2c0b-4c4c-9b41-96c01cd8258a":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6e4e638e-5981-40d1-a35b-ea078d4b76ea","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a0c5771c-cd0d-4f4d-9f87-e52d89b31daa","type":"PanTool"},{"id":"161f527e-63b3-4a68-9759-a06aad4ef648","type":"WheelZoomTool"},{"id":"b4efc6b4-44d2-4cec-83e9-b00a8df9fd25","type":"BoxZoomTool"},{"id":"c5865bb0-46ca-4dd6-b592-18e398f95a0b","type":"SaveTool"},{"id":"77e2ed10-f331-4035-8fe5-7e5ecd2715c3","type":"ResetTool"},{"id":"0c00a07f-884b-4f52-ac78-50c5e6dccaf3","type":"HelpTool"}]},"id":"560b91ae-6c5f-4301-af06-375354eaf8c2","type":"Toolbar"},{"attributes":{"callback":null},"id":"db736227-38f7-46ac-aa7d-3d7e3110b7db","type":"DataRange1d"},{"attributes":{"plot":{"id":"49d8aa4f-fe52-4a65-8120-d2fcd8a5b5fd","subtype":"Figure","type":"Plot"}},"id":"a0c5771c-cd0d-4f4d-9f87-e52d89b31daa","type":"PanTool"},{"attributes":{"plot":{"id":"49d8aa4f-fe52-4a65-8120-d2fcd8a5b5fd","subtype":"Figure","type":"Plot"}},"id":"77e2ed10-f331-4035-8fe5-7e5ecd2715c3","type":"ResetTool"},{"attributes":{"legends":[["Temp.",[{"id":"ecc1be0b-3684-4cc5-9803-024b225d6a87","type":"GlyphRenderer"}]]],"plot":{"id":"49d8aa4f-fe52-4a65-8120-d2fcd8a5b5fd","subtype":"Figure","type":"Plot"}},"id":"e7ada4e0-5d36-4b61-a617-bec8a07d82b9","type":"Legend"},{"attributes":{"dimension":1,"plot":{"id":"49d8aa4f-fe52-4a65-8120-d2fcd8a5b5fd","subtype":"Figure","type":"Plot"},"ticker":{"id":"ab21e096-098e-488f-8f37-ee4998d984ec","type":"BasicTicker"}},"id":"b94f9c01-f57b-4f44-9b1f-9adc9a06ba0e","type":"Grid"},{"attributes":{},"id":"3247ffe5-c5bc-49a1-bc52-9d66b14bc1f8","type":"BasicTickFormatter"},{"attributes":{"axis_label":"y","formatter":{"id":"292a20cc-dbe6-4f53-9799-b58b308e6de3","type":"BasicTickFormatter"},"plot":{"id":"49d8aa4f-fe52-4a65-8120-d2fcd8a5b5fd","subtype":"Figure","type":"Plot"},"ticker":{"id":"ab21e096-098e-488f-8f37-ee4998d984ec","type":"BasicTicker"}},"id":"0623088a-b2ab-499c-b3d9-2e0f9fdfb89f","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"8953b4a5-7d01-48d6-a35e-b87ec5e6f83c","type":"Line"},{"attributes":{"plot":{"id":"49d8aa4f-fe52-4a65-8120-d2fcd8a5b5fd","subtype":"Figure","type":"Plot"},"ticker":{"id":"ee456ee0-9b3f-4242-ac42-b3d862495ef5","type":"BasicTicker"}},"id":"0712dd1a-e8fd-40e3-9f69-5ac1078ed54f","type":"Grid"},{"attributes":{"below":[{"id":"c7f5ce2d-b709-4277-b350-1cd4d91785f1","type":"LinearAxis"}],"left":[{"id":"0623088a-b2ab-499c-b3d9-2e0f9fdfb89f","type":"LinearAxis"}],"renderers":[{"id":"c7f5ce2d-b709-4277-b350-1cd4d91785f1","type":"LinearAxis"},{"id":"0712dd1a-e8fd-40e3-9f69-5ac1078ed54f","type":"Grid"},{"id":"0623088a-b2ab-499c-b3d9-2e0f9fdfb89f","type":"LinearAxis"},{"id":"b94f9c01-f57b-4f44-9b1f-9adc9a06ba0e","type":"Grid"},{"id":"6e4e638e-5981-40d1-a35b-ea078d4b76ea","type":"BoxAnnotation"},{"id":"e7ada4e0-5d36-4b61-a617-bec8a07d82b9","type":"Legend"},{"id":"ecc1be0b-3684-4cc5-9803-024b225d6a87","type":"GlyphRenderer"}],"title":{"id":"31c9d0b9-d95a-45a7-8e8a-09cfa1083ce7","type":"Title"},"tool_events":{"id":"04eee0f4-f032-4743-9e8c-53b2005e3a4f","type":"ToolEvents"},"toolbar":{"id":"560b91ae-6c5f-4301-af06-375354eaf8c2","type":"Toolbar"},"x_range":{"id":"db736227-38f7-46ac-aa7d-3d7e3110b7db","type":"DataRange1d"},"y_range":{"id":"b050c516-5e98-4a90-a1e0-a7fa29aac340","type":"DataRange1d"}},"id":"49d8aa4f-fe52-4a65-8120-d2fcd8a5b5fd","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"1cb289bc-dcef-45b8-85f9-d907b87f7ae0","type":"ColumnDataSource"},"glyph":{"id ...

# %%
from bokeh.sampledata.autompg import autompg as df
df
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# 5    15.0    8  429.0  198    4341   10.0  70       1
# 6    14.0    8  454.0  220    4354    9.0  70       1
# 7    14.0    8  440.0  215    4312    8.5  70       1
# 8    14.0    8  455.0  225    4425   10.0  70       1
# 9    15.0    8  390.0  190    3850    8.5  70       1
# 10   15.0    8  383.0  170    3563   10.0  70       1
# 11   14.0    8  340.0  160    3609    8.0  70       1
# 12   15.0    8  400.0  150    3761    9.5  70       1
# 13   14.0    8  455.0  225    3086   10.0  70       1
# 14   24.0    4  113.0   95    2372   15.0  70       3
# 15   22.0    6  198.0   95    2833   15.5  70       1
# 16   18.0    6  199.0   97    2774   15.5  70       1
# 17   21.0    6  200.0   85    2587   16.0  70       1
# 18   27.0    4   97.0   88    2130   14.5  70       3
# 19   26.0    4   97.0   46    1835   20.5  70       2
# 20   25.0    4  110.0   87    2672   17.5  70       2
# 21   24.0    4  107.0   90    2430   14.5  70       2
# 22   25.0    4  104.0   95    2375   17.5  70       2
# 23   26.0    4  121.0  113    2234   12.5  70       2
# 24   21.0    6  199.0   90    2648   15.0  70       1
# 25   10.0    8  360.0  215    4615   14.0  70       1
# 26   10.0    8  307.0  200    4376   15.0  70       1
# 27   11.0    8  318.0  210    4382   13.5  70       1
# 28    9.0    8  304.0  193    4732   18.5  70       1
# 29   27.0    4   97.0   88    2130   14.5  71       3
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 362  28.0    4  112.0   88    2605   19.6  82       1
# 363  27.0    4  112.0   88    2640   18.6  82       1
# 364  34.0    4  112.0   88    2395   18.0  82       1
# 365  31.0    4  112.0   85    2575   16.2  82       1
# 366  29.0    4  135.0   84    2525   16.0  82       1
# 367  27.0    4  151.0   90    2735   18.0  82       1
# 368  24.0    4  140.0   92    2865   16.4  82       1
# 369  36.0    4  105.0   74    1980   15.3  82       2
# 370  37.0    4   91.0   68    2025   18.2  82       3
# 371  31.0    4   91.0   68    1970   17.6  82       3
# 372  38.0    4  105.0   63    2125   14.7  82       1
# 373  36.0    4   98.0   70    2125   17.3  82       1
# 374  36.0    4  120.0   88    2160   14.5  82       3
# 375  36.0    4  107.0   75    2205   14.5  82       3
# 376  34.0    4  108.0   70    2245   16.9  82       3
# 377  38.0    4   91.0   67    1965   15.0  82       3
# 378  32.0    4   91.0   67    1965   15.7  82       3
# 379  38.0    4   91.0   67    1995   16.2  82       3
# 380  25.0    6  181.0  110    2945   16.4  82       1
# 381  38.0    6  262.0   85    3015   17.0  82       1
# 382  26.0    4  156.0   92    2585   14.5  82       1
# 383  22.0    6  232.0  112    2835   14.7  82       1
# 384  32.0    4  144.0   96    2665   13.9  82       3
# 385  36.0    4  135.0   84    2370   13.0  82       1
# 386  27.0    4  151.0   90    2950   17.3  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                                   name
# 0            chevrolet chevelle malibu
# 1                    buick skylark 320
# 2                   plymouth satellite
# 3                        amc rebel sst
# 4                          ford torino
# 5                     ford galaxie 500
# 6                     chevrolet impala
# 7                    plymouth fury iii
# 8                     pontiac catalina
# 9                   amc ambassador dpl
# 10                 dodge challenger se
# 11                  plymouth 'cuda 340
# 12               chevrolet monte carlo
# 13             buick estate wagon (sw)
# 14               toyota corona mark ii
# 15                     plymouth duster
# 16                          amc hornet
# 17                       ford maverick
# 18                        datsun pl510
# 19        volkswagen 1131 deluxe sedan
# 20                         peugeot 504
# 21                         audi 100 ls
# 22                            saab 99e
# 23                            bmw 2002
# 24                         amc gremlin
# 25                           ford f250
# 26                           chevy c20
# 27                          dodge d200
# 28                            hi 1200d
# 29                        datsun pl510
# ..                                 ...
# 362                 chevrolet cavalier
# 363           chevrolet cavalier wagon
# 364          chevrolet cavalier 2-door
# 365         pontiac j2000 se hatchback
# 366                     dodge aries se
# 367                    pontiac phoenix
# 368               ford fairmont futura
# 369                volkswagen rabbit l
# 370                 mazda glc custom l
# 371                   mazda glc custom
# 372             plymouth horizon miser
# 373                     mercury lynx l
# 374                   nissan stanza xe
# 375                       honda accord
# 376                     toyota corolla
# 377                        honda civic
# 378                 honda civic (auto)
# 379                      datsun 310 gx
# 380              buick century limited
# 381  oldsmobile cutlass ciera (diesel)
# 382         chrysler lebaron medallion
# 383                     ford granada l
# 384                   toyota celica gt
# 385                  dodge charger 2.2
# 386                   chevrolet camaro
# 387                    ford mustang gl
# 388                          vw pickup
# 389                      dodge rampage
# 390                        ford ranger
# 391                         chevy s-10
#
# [392 rows x 9 columns]

# %%
from bokeh.charts import Scatter, output_file, show
output_notebook()
p = Scatter(df, x='mpg', y='hp', title="HP vs MPG",
            xlabel="Miles Per Gallon", ylabel="Horsepower")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="397332c0-ad81-44db-a9a4-32cff5db6384">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="54de04a0-6eaa-49ee-b24b-d0982f97a6ab"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("54de04a0-6eaa-49ee-b24b-d0982f97a6ab");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '54de04a0-6eaa-49ee-b24b-d0982f97a6ab' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0e9de1b3-b54b-4236-b8e4-d84924f0d278":{"roots":{"references":[{"attributes":{"plot":{"id":"c5a1b945-d4d3-4bce-b01f-0c0a8d69a9fd","subtype":"Chart","type":"Plot"}},"id":"4af9bca1-7f8f-4ee5-b38c-8eb9a69ffddb","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d75570f6-f0b2-4245-9f2b-fde5722fd1f5","type":"BoxAnnotation"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"71b5f865-619f-468d-b421-cb255152c529","type":"PanTool"},{"id":"f3398afa-1785-407f-a523-3c309dea1265","type":"WheelZoomTool"},{"id":"900b2781-5ddc-40a1-a71d-99870994e07b","type":"BoxZoomTool"},{"id":"4af9bca1-7f8f-4ee5-b38c-8eb9a69ffddb","type":"SaveTool"},{"id":"92f6cc1a-e384-4ad0-b431-790618d5a47b","type":"ResetTool"},{"id":"0f9b2494-e527-43bf-8a7a-478547e03d83","type":"HelpTool"}]},"id":"3b2a41aa-435d-4483-9cc5-72016d2edf47","type":"Toolbar"},{"attributes":{"plot":{"id":"c5a1b945-d4d3-4bce-b01f-0c0a8d69a9fd","subtype":"Chart","type":"Plot"}},"id":"f3398afa-1785-407f-a523-3c309dea1265","type":"WheelZoomTool"},{"attributes":{"location":"top_left","plot":{"id":"c5a1b945-d4d3-4bce-b01f-0c0a8d69a9fd","subtype":"Chart","type":"Plot"}},"id":"4167c942-92b7-4933-b0f5-c53aba4724fb","type":"Legend"},{"attributes":{"callback":null,"end":50.36,"start":5.24},"id":"13cfc552-1a14-4281-b708-1600f91243a4","type":"Range1d"},{"attributes":{},"id":"57a94e38-8230-4179-92ac-c0ac3b76c808","type":"BasicTicker"},{"attributes":{"axis_label":"Miles Per Gallon","formatter":{"id":"b6647c6d-e53f-4d44-8fa5-506fa06fc19d","type":"BasicTickFormatter"},"plot":{"id":"c5a1b945-d4d3-4bce-b01f-0c0a8d69a9fd","subtype":"Chart","type":"Plot"},"ticker":{"id":"57a94e38-8230-4179-92ac-c0ac3b76c808","type":"BasicTicker"}},"id":"7ebe0a9d-6daa-44eb-856b-a5a5d7911043","type":"LinearAxis"},{"attributes":{"below":[{"id":"7ebe0a9d-6daa-44eb-856b-a5a5d7911043","type":"LinearAxis"}],"left":[{"id":"e675d8a6-190c-435b-973c-f3d68c14dc7c","type":"LinearAxis"}],"renderers":[{"id":"d75570f6-f0b2-4245-9f2b-fde5722fd1f5","type":"BoxAnnotation"},{"id":"2fb72d5b-9169-4b70-bc96-bbd5f8477f59","type":"GlyphRenderer"},{"id":"4167c942-92b7-4933-b0f5-c53aba4724fb","type":"Legend"},{"id":"7ebe0a9d-6daa-44eb-856b-a5a5d7911043","type":"LinearAxis"},{"id":"e675d8a6-190c-435b-973c-f3d68c14dc7c","type":"LinearAxis"},{"id":"33803218-d5ce-4b1b-8432-9f696c14cd92","type":"Grid"},{"id":"f5e3bd7a-f3ad-4f61-9cd8-7c5f8b44f33d","type":"Grid"}],"title":{"id":"95391f22-8a89-4930-8362-e0d45c980f89","type":"Title"},"tool_events":{"id":"98587a19-0cab-4312-8b2f-f25c5b74275e","type":"ToolEvents"},"toolbar":{"id":"3b2a41aa-435d-4483-9cc5-72016d2edf47","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"13cfc552-1a14-4281-b708-1600f91243a4","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"6211cfe7-043f-4c11-8901-c79e7d04a806","type":"Range1d"}},"id":"c5a1b945-d4d3-4bce-b01f-0c0a8d69a9fd","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"c5a1b945-d4d3-4bce-b01f-0c0a8d69a9fd","subtype":"Chart","type":"Plot"}},"id":"0f9b2494-e527-43bf-8a7a-478547e03d83","type":"HelpTool"},{"attributes":{"plot":null,"text":"HP vs MPG"},"id":"95391f22-8a89-4930-8362-e0d45c980f89","type":"Title"},{"attributes":{"overlay":{"id":"d75570f6-f0b2-4245-9f2b-fde5722fd1f5","type":"BoxAnnotation"},"plot":{"id":"c5a1b945-d4d3-4bce-b01f-0c0a8d69a9fd","subtype":"Chart","type":"Plot"}},"id":"900b2781-5ddc-40a1-a71d-99870994e07b","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"c09065ae-b661-44af-9631-6b73f1bd5523","type":"ColumnDataSource"},"glyph":{"id":"362b4d4b-ba35-443d-85f7-e8d58157e5c2","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2fb72d5b-91 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
import pandas
df = pandas.read_csv("universities.csv")
df
# Out:
#                School        Type  Median_SAT  Acceptance_Rate_Perc  \
# 0             Amherst    Lib Arts        1315                    26
# 1             Barnard    Lib Arts        1220                    57
# 2               Bates    Lib Arts        1240                    40
# 3            Berkeley  University        1176                    36
# 4             Bowdoin    Lib Arts        1300                    28
# 5               Brown  University        1281                    23
# 6           Bryn Mawr    Lib Arts        1255                    60
# 7            Cal Tech  University        1400                    30
# 8            Carleton    Lib Arts        1300                    44
# 9     Carnegie Mellon  University        1225                    63
# 10  Claremont McKenna    Lib Arts        1260                    40
# 11              Colby    Lib Arts        1200                    50
# 12            Colgate    Lib Arts        1258                    42
# 13           Columbia  University        1268                    28
# 14            Cornell  University        1280                    29
# 15           Davidson    Lib Arts        1230                    40
# 16               Duke  University        1310                    24
# 17         Georgetown  University        1278                    23
# 18           Grinnell    Lib Arts        1244                    71
# 19           Hamilton    Lib Arts        1215                    42
# 20            Harvard  University        1370                    17
# 21          Haverford    Lib Arts        1285                    39
# 22      Johns Hopkins  University        1290                    47
# 23         Middlebury    Lib Arts        1255                    29
# 24                MIT  University        1357                    29
# 25      Mount Holyoke    Lib Arts        1200                    65
# 26       Northwestern  University        1230                    46
# 27            Oberlin    Lib Arts        1247                    58
# 28         Occidental    Lib Arts        1170                    53
# 29             Pomona    Lib Arts        1320                    37
# 30          Princeton  University        1340                    16
# 31               Rice  University        1327                    23
# 32              Smith    Lib Arts        1195                    61
# 33           Stanford  University        1370                    17
# 34         Swarthnore    Lib Arts        1310                    28
# 35           Syracuse  University        1350                    19
# 36         U Michigan  University        1195                    59
# 37       U of Chicago  University        1300                    44
# 38     U of Rochester  University        1155                    55
# 39     U Pennsylvania  University        1280                    40
# 40               U Va  University        1218                    36
# 41               UCLA  University        1142                    42
# 42                UNC  University        1109                    31
# 43             Vassar    Lib Arts        1287                    47
# 44  Washington U (MO)  University        1225                    53
# 45  Washinton and Lee    Lib Arts        1234                    33
# 46          Wellesley    Lib Arts        1250                    53
# 47      Wesleyan (CT)    Lib Arts        1290                    39
# 48           Williams    Lib Arts        1336                    32
# 49               Yale  University        1350                    18
#
#    Expenditures_per_Student  Graduation_perc
# 0                  $23,972                93
# 1                  $15,887                80
# 2                  $15,798                88
# 3                  $26,031                68
# 4                  $23,132                90
# 5                  $26,621                90
# 6                  $16,962                84
# 7                 $112,488                75
# 8                  $14,313                80
# 9                  $36,967                77
# 10                 $18,339                74
# 11                 $16,984                84
# 12                 $15,768                85
# 13                 $50,466                90
# 14                 $40,850                83
# 15                 $15,948                89
# 16                 $43,454                91
# 17                 $25,426                89
# 18                 $20,070                73
# 19                 $18,649                85
# 20                 $51,609                90
# 21                 $17,476                87
# 22                 $50,006                86
# 23                 $22,246                92
# 24                 $62,442                86
# 25                 $21,022                83
# 26                 $31,736                82
# 27                 $21,231                77
# 28                 $18,172                72
# 29                 $24,001                80
# 30                 $52,935                93
# 31                 $29,403                88
# 32                 $22,743                87
# 33                 $68,113                88
# 34                 $24,738                88
# 35                 $36,850                90
# 36                 $24,038                77
# 37                 $42,830                73
# 38                 $42,456                73
# 39                 $33,970                86
# 40                 $21,301                88
# 41                 $29,544                61
# 42                 $21,652                73
# 43                 $18,161                84
# 44                 $43,871                76
# 45                 $16,198                78
# 46                 $25,091                86
# 47                 $17,953                91
# 48                 $21,394                93
# 49                 $57,714                93

# %%
from bokeh.charts import Scatter, output_file, show

output_notebook()


p = Scatter(df, x='Acceptance_Rate_Perc', y='Median_SAT', title="Universities",
            xlabel="Acceptance Rate", ylabel="Media SAT")

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="86f6ce15-3d9c-4838-aa03-3accd42158b0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="8d3c56da-0232-4bab-87ae-4777de84a4b7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8d3c56da-0232-4bab-87ae-4777de84a4b7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8d3c56da-0232-4bab-87ae-4777de84a4b7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5a755532-23f5-402e-b886-e37d7029648d":{"roots":{"references":[{"attributes":{},"id":"6f630c7e-f097-41ba-9275-6a7fc57a97b2","type":"BasicTicker"},{"attributes":{},"id":"152c63cd-2759-4d4c-8f8a-f7f727228615","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Media SAT","formatter":{"id":"024607d2-0ed2-4063-8606-f566fadc9075","type":"BasicTickFormatter"},"plot":{"id":"2543a4da-77af-4ae3-95a6-bbfa69496512","subtype":"Chart","type":"Plot"},"ticker":{"id":"6f630c7e-f097-41ba-9275-6a7fc57a97b2","type":"BasicTicker"}},"id":"c925021a-c106-4171-853b-0386b14faa0c","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[26,57,40,36,28,23,60,30,44,63,40,50,42,28,29,40,24,23,71,42,17,39,47,29,29,65,46,58,53,37,16,23,61,17,28,19,59,44,55,40,36,42,31,47,53,33,53,39,32,18],"y_values":[1315,1220,1240,1176,1300,1281,1255,1400,1300,1225,1260,1200,1258,1268,1280,1230,1310,1278,1244,1215,1370,1285,1290,1255,1357,1200,1230,1247,1170,1320,1340,1327,1195,1370,1310,1350,1195,1300,1155,1280,1218,1142,1109,1287,1225,1234,1250,1290,1336,1350]}},"id":"1ffbcf6f-ed69-4c92-9991-5fba3b72de33","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":1429.1,"start":1079.9},"id":"0f09b128-b73a-46c6-8331-be254dee6487","type":"Range1d"},{"attributes":{"callback":null,"end":76.5,"start":10.5},"id":"97bc8002-53bb-4b45-b92b-90320e100da4","type":"Range1d"},{"attributes":{"axis_label":"Acceptance Rate","formatter":{"id":"152c63cd-2759-4d4c-8f8a-f7f727228615","type":"BasicTickFormatter"},"plot":{"id":"2543a4da-77af-4ae3-95a6-bbfa69496512","subtype":"Chart","type":"Plot"},"ticker":{"id":"374deb01-6036-42e8-9fe3-554be2e764c0","type":"BasicTicker"}},"id":"b2188138-4164-4587-9b0a-a3ee370254d2","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f8dacc6c-9334-430d-8bca-1ed60a0c4cc3","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"b2188138-4164-4587-9b0a-a3ee370254d2","type":"LinearAxis"}],"left":[{"id":"c925021a-c106-4171-853b-0386b14faa0c","type":"LinearAxis"}],"renderers":[{"id":"f8dacc6c-9334-430d-8bca-1ed60a0c4cc3","type":"BoxAnnotation"},{"id":"552c9946-882a-4840-b7d4-5c265bf871f4","type":"GlyphRenderer"},{"id":"8b2482cf-3a66-4002-ab44-d6894f600ac6","type":"Legend"},{"id":"b2188138-4164-4587-9b0a-a3ee370254d2","type":"LinearAxis"},{"id":"c925021a-c106-4171-853b-0386b14faa0c","type":"LinearAxis"},{"id":"5557c4d7-dc4b-45f1-87e3-c70d7448eba6","type":"Grid"},{"id":"d30f2fa4-c47a-44ed-b642-ec1c912c29eb","type":"Grid"}],"title":{"id":"fb8e29fb-5118-433e-aaa2-4f43505e8df7","type":"Title"},"tool_events":{"id":"ae0121da-baeb-4a98-9121-980509eeb223","type":"ToolEvents"},"toolbar":{"id":"02032c8f-aa6b-45d7-b7e6-b83d5f9398aa","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"97bc8002-53bb-4b45-b92b-90320e100da4","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"0f09b128-b73a-46c6-8331-be254dee6487","type":"Range1d"}},"id":"2543a4da-77af-4ae3-95a6-bbfa69496512","subtype":"Chart","type":"Plot"},{"attributes":{"plot":null,"text":"Universities"},"id":"fb8e29fb-5118-433e-aaa2-4f43505e8df7","type":"Title"},{"attributes":{"overlay":{"id":"f8dacc6c-9334-430d-8bca-1ed60a0c4cc3","type":"BoxAnnotation"},"plot":{"id":"2543a4da-77af-4ae3-95a6-bbfa69496512","subtype":"Chart","type":"Plot"}},"id":"b167b627-c7a6-4e43-9498-fe33dcd75eeb","type":"BoxZoomTool"},{"attributes":{},"id":"024607d2-0ed2-4063-8606-f566fadc9075","type":"Basi ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %%
p = Scatter(df, x='Acceptance_Rate_Perc', y='Graduation_perc', title="Universities",
            xlabel="Acceptance Rate", ylabel="Graduation_perc")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="da3b907e-d00f-45c0-ba4a-e364bfc8821b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("da3b907e-d00f-45c0-ba4a-e364bfc8821b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'da3b907e-d00f-45c0-ba4a-e364bfc8821b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1b3ebdf2-d8da-4771-b360-6d8728cbda0c":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"c884ad68-8015-425a-a517-e07a79f5ea87","subtype":"Chart","type":"Plot"},"ticker":{"id":"4e69a517-c2b7-4ef1-b004-a58ca0e47127","type":"BasicTicker"}},"id":"f4b61b2e-9417-49ae-b878-98d8ee6ec087","type":"Grid"},{"attributes":{"callback":null,"end":96.2,"start":57.8},"id":"228873b5-e3f1-4995-a2e7-742065f9f241","type":"Range1d"},{"attributes":{"below":[{"id":"f4857277-1c14-489b-ba1a-871a3fe60a92","type":"LinearAxis"}],"left":[{"id":"2a72902b-e23a-4b47-b353-40309e37df03","type":"LinearAxis"}],"renderers":[{"id":"f5483a59-69ff-446f-be44-e591f1267744","type":"BoxAnnotation"},{"id":"decf8a6b-99a0-46d6-8729-c477f698e8e5","type":"GlyphRenderer"},{"id":"bb10ffb0-5a19-4282-ae33-c56457feff25","type":"Legend"},{"id":"f4857277-1c14-489b-ba1a-871a3fe60a92","type":"LinearAxis"},{"id":"2a72902b-e23a-4b47-b353-40309e37df03","type":"LinearAxis"},{"id":"47b5952e-4dba-4e34-8c3e-0f171e3c4e17","type":"Grid"},{"id":"f4b61b2e-9417-49ae-b878-98d8ee6ec087","type":"Grid"}],"title":{"id":"fe550e9b-f3f5-40fd-a72f-7da61123b88e","type":"Title"},"tool_events":{"id":"8e5fbc78-8203-45a8-9483-65ed5ccfb399","type":"ToolEvents"},"toolbar":{"id":"8c54b79b-4836-45b0-ab22-19ea54da5586","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"8254b228-8a45-470c-9b8b-a902cfe70536","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"228873b5-e3f1-4995-a2e7-742065f9f241","type":"Range1d"}},"id":"c884ad68-8015-425a-a517-e07a79f5ea87","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"c884ad68-8015-425a-a517-e07a79f5ea87","subtype":"Chart","type":"Plot"}},"id":"cc6a533a-6354-483e-8b04-c2dea80dc6ff","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a6b96a65-ca85-4d51-ad40-8c696c05a5c4","type":"PanTool"},{"id":"20b70fd4-49b6-4451-8d61-6ca8c42f84ec","type":"WheelZoomTool"},{"id":"1eb395d7-c117-4955-a005-fc2bbd5dbafd","type":"BoxZoomTool"},{"id":"cc6a533a-6354-483e-8b04-c2dea80dc6ff","type":"SaveTool"},{"id":"df65589b-6f84-4a41-81b6-96d324660410","type":"ResetTool"},{"id":"7a7b9c29-c48d-44a6-8f05-37365e6edad1","type":"HelpTool"}]},"id":"8c54b79b-4836-45b0-ab22-19ea54da5586","type":"Toolbar"},{"attributes":{},"id":"4e69a517-c2b7-4ef1-b004-a58ca0e47127","type":"BasicTicker"},{"attributes":{"data_source":{"id":"b9a632c3-3e98-4100-8e80-2b21a59b297b","type":"ColumnDataSource"},"glyph":{"id":"36ad4a44-66c7-4432-bad9-a095f6fdeb2d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"decf8a6b-99a0-46d6-8729-c477f698e8e5","type":"GlyphRenderer"},{"attributes":{},"id":"8e5fbc78-8203-45a8-9483-65ed5ccfb399","type":"ToolEvents"},{"attributes":{"plot":{"id":"c884ad68-8015-425a-a517-e07a79f5ea87","subtype":"Chart","type":"Plot"}},"id":"df65589b-6f84-4a41-81b6-96d324660410","type":"ResetTool"},{"attributes":{"location":"top_left","plot":{"id":"c884ad68-8015-425a-a517-e07a79f5ea87","subtype":"Chart","type":"Plot"}},"id":"bb10ffb0-5a19-4282-ae33-c56457feff25","type":"Legend"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f5483a59-69ff-446f-be44-e591f1267744","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":76.5,"start":10.5},"id":"8254b228-8a45-470c-9b8b-a902cfe70536","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"36ad4a44-66c7-4432-bad9-a095f6fdeb2d","type":"Circle"},{"attributes":{"plot":{"id":"c884ad68-8015-425a-a517-e07a79f5ea87","subtype":"Chart","type":"Plot"}},"id":"a6b96a65-ca85-4d51 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>

# %%
p = Scatter(df, x='Median_SAT', y='Graduation_perc', title="Universities",
            xlabel="Median_SAT", ylabel="Graduation_perc")

show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="d7ff7044-27fa-49f4-9019-662dc17cc217"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d7ff7044-27fa-49f4-9019-662dc17cc217");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd7ff7044-27fa-49f4-9019-662dc17cc217' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c50e17e2-0e5e-4315-a681-82f4e0732eee":{"roots":{"references":[{"attributes":{"callback":null,"end":1429.1,"start":1079.9},"id":"259c2062-20e8-465a-9b4a-0313efb2fd11","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"e63b89a0-7746-43b1-9b52-e6bca5604c7e","type":"Circle"},{"attributes":{"plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"}},"id":"de617f38-a039-4556-945a-0dc9b158d91a","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"},"ticker":{"id":"bfcf5c9c-905b-4a1c-9388-19a249a2cd08","type":"BasicTicker"}},"id":"13a28f56-25b2-4295-ba7b-51c6c3688396","type":"Grid"},{"attributes":{"plot":null,"text":"Universities"},"id":"f06f7502-db3f-4898-a6d9-e0b6025df900","type":"Title"},{"attributes":{"plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"}},"id":"8c3c7af4-b83b-49e6-a556-fe0ae01f7050","type":"HelpTool"},{"attributes":{"axis_label":"Graduation_perc","formatter":{"id":"34ed645d-5330-4849-bd49-9ac397e53072","type":"BasicTickFormatter"},"plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"},"ticker":{"id":"bfcf5c9c-905b-4a1c-9388-19a249a2cd08","type":"BasicTicker"}},"id":"40739cae-5f21-4003-96f6-e0285de2d2c7","type":"LinearAxis"},{"attributes":{"data_source":{"id":"efcbb1a5-c046-4688-9657-783ffcbfaa11","type":"ColumnDataSource"},"glyph":{"id":"e63b89a0-7746-43b1-9b52-e6bca5604c7e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6efa3539-a60c-4a93-a68e-6c84923473d9","type":"GlyphRenderer"},{"attributes":{},"id":"116a1767-e8a4-483d-911c-e2beb7dd82b1","type":"BasicTicker"},{"attributes":{"location":"top_left","plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"}},"id":"1736abea-f8a8-47e5-904f-476563951e7c","type":"Legend"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"55193812-b3ec-48b9-b442-71b124ae974d","type":"PanTool"},{"id":"de617f38-a039-4556-945a-0dc9b158d91a","type":"WheelZoomTool"},{"id":"f9f0b58b-d67d-4969-9400-a88744557932","type":"BoxZoomTool"},{"id":"925f5ca3-6ae1-47af-91c0-edb81b9de250","type":"SaveTool"},{"id":"3ea6c27c-5bd6-4c89-90a6-fbf44e20b221","type":"ResetTool"},{"id":"8c3c7af4-b83b-49e6-a556-fe0ae01f7050","type":"HelpTool"}]},"id":"13200c96-4812-4fdb-907f-9fcaec3587ef","type":"Toolbar"},{"attributes":{"plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"},"ticker":{"id":"116a1767-e8a4-483d-911c-e2beb7dd82b1","type":"BasicTicker"}},"id":"01bd383e-1c18-4dac-879b-fdf8d33cd78d","type":"Grid"},{"attributes":{"plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"}},"id":"925f5ca3-6ae1-47af-91c0-edb81b9de250","type":"SaveTool"},{"attributes":{},"id":"34ed645d-5330-4849-bd49-9ac397e53072","type":"BasicTickFormatter"},{"attributes":{},"id":"bfcf5c9c-905b-4a1c-9388-19a249a2cd08","type":"BasicTicker"},{"attributes":{},"id":"b54ed0b8-b239-4cbe-b948-9e540d142426","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"7b332579-a493-4da2-88de-643bef5ddb29","type":"BoxAnnotation"},"plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"}},"id":"f9f0b58b-d67d-4969-9400-a88744557932","type":"BoxZoomTool"},{"attributes":{},"id":"07f1cb81-33bd-4c3a-9a9f-a085cc80900f","type":"ToolEvents"},{"attributes":{"plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"}},"id":"3ea6c27c-5bd6-4c89-90a6-fbf44e20b221","type":"ResetTool"},{"attributes":{"plot":{"id":"d233b3cc-2c4e-4a2a-a952-00c57170592c","subtype":"Chart","type":"Plot"}},"id":"55193812-b3ec-48b9-b442-71b124ae974d","type":"PanTool"},{"attributes":{"callback":null,"column_n ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>
